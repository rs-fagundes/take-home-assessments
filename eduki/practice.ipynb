# %%
import pandas as pd

# %%
path_file = 'csv/ga4_master_events.csv'

df = pd.read_csv(path_file)

# %%
df.head()
# Out:
#    event_date   event_timestamp     event_name user_pseudo_id  session_id  \
# 0  2025-01-06  1736136977000000  session_start        u_03455  s_00000001
# 1  2025-01-06  1736136977000000      page_view        u_03455  s_00000001
# 2  2025-01-06  1736136980639129      page_view        u_03455  s_00000001
# 3  2025-01-06  1736136980537900      page_view        u_03455  s_00000001
# 4  2025-01-06  1736136988397123      page_view        u_03455  s_00000001
#
#                       page_location traffic_default_channel_grouping  \
# 0                               NaN                   Organic Search
# 1    https://www.eduki.example/blog                   Organic Search
# 2  https://www.eduki.example/author                   Organic Search
# 3  https://www.eduki.example/course                   Organic Search
# 4  https://www.eduki.example/course                   Organic Search
#
#   traffic_source traffic_medium traffic_campaign device_category geo_country  \
# ...
